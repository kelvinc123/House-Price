# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import re
from importlib import reload

from _lib.preprocess import preprocess_missing as prep
from _lib.preprocess import get_instruction as info
from _lib.preprocess_test import preprocess_missing as prep_test
from _lib.create_output import output

# %%
df = pd.read_csv("_database/Input/train.csv", index_col = 0)

df = prep(df)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1          60       RL         65.0     8450   Pave    NA      Reg
# 2          20       RL         80.0     9600   Pave    NA      Reg
# 3          60       RL         68.0    11250   Pave    NA      IR1
# 4          70       RL         60.0     9550   Pave    NA      IR1
# 5          60       RL         84.0    14260   Pave    NA      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0     NA    NA          NA
# 2          Lvl    AllPub       FR2  ...        0     NA    NA          NA
# 3          Lvl    AllPub    Inside  ...        0     NA    NA          NA
# 4          Lvl    AllPub    Corner  ...        0     NA    NA          NA
# 5          Lvl    AllPub       FR2  ...        0     NA    NA          NA
#
#    MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# ...

# %%
for col in df.columns:
    plt.figure(figsize = (20,12))
    if str(df[col].dtype) == "category":
        sns.boxplot(x = col, y = "SalePrice", data = df)
        plt.title("{} vs SalePrice".format(col))
    else:
        sns.relplot(x = col, y = "SalePrice", data = df, kind = "scatter")
    plt.savefig("_database/plot2/{}.png".format(col))
# Out:
# C:\Anaconda\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# C:\Anaconda\Anaconda3\lib\site-packages\seaborn\axisgrid.py:324: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(nrow, ncol, **kwargs)
# ...

# %%
df[df["1stFlrSF"] > 4000]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299         60       RL        313.0    63887   Pave    NA      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1299         Bnk    AllPub    Corner  ...      480     Gd    NA          NA
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 1299       0      1   2008      New        Partial     160000
#
# [1 rows x 80 columns]

# %%
df[df["BsmtFinSF1"] > 3000]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299         60       RL        313.0    63887   Pave    NA      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1299         Bnk    AllPub    Corner  ...      480     Gd    NA          NA
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 1299       0      1   2008      New        Partial     160000
#
# [1 rows x 80 columns]

# %%
df[df["LotFrontage"] > 250]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 935          20       RL        313.0    27650   Pave    NA      IR2
# 1299         60       RL        313.0    63887   Pave    NA      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 935          HLS    AllPub    Inside  ...        0     NA    NA          NA
# 1299         Bnk    AllPub    Corner  ...      480     Gd    NA          NA
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 935        0     11   2008       WD         Normal     242000
# 1299       0      1   2008      New        Partial     160000
#
# [2 rows x 80 columns]

# %%
df[(df["LowQualFinSF"] > 500) & (df["SalePrice"] > 400000)]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 186         75       RM         90.0    22950   Pave    NA      IR2
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                   ...
# 186         Lvl    AllPub    Inside  ...        0     NA  GdPrv          NA
#
#     MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 186       0      6   2006       WD         Normal     475000
#
# [1 rows x 80 columns]

# %%
df[df["MiscVal"] > 5000]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 347          20       RL    70.049958    12772   Pave    NA      IR1
# 1231         90       RL    70.049958    18890   Pave    NA      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 347          Lvl    AllPub   CulDSac  ...        0     NA    NA        Gar2
# 1231         Lvl    AllPub    Inside  ...        0     NA    NA        Gar2
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 347    15500      4   2007       WD         Normal     151500
# 1231    8300      8   2007       WD         Normal     190000
#
# [2 rows x 80 columns]

# %%
df[(df["PoolArea"] > 0) & (df["SalePrice"] > 500000)]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1183         60       RL        160.0    15623   Pave    NA      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1183         Lvl    AllPub    Corner  ...      555     Ex  MnPrv          NA
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 1183       0      7   2007       WD        Abnorml     745000
#
# [1 rows x 80 columns]

# %%
df[(df["RoofMatl"] == "WdShngl") & (df["SalePrice"] > 600000)]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 692         60       RL        104.0    21535   Pave    NA      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 692         Lvl    AllPub    Corner  ...        0     NA    NA          NA
#
#     MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 692       0      1   2007       WD         Normal     755000
#
# [1 rows x 80 columns]

# %%
df[(df["RoofStyle"] == "Gable") & (df["SalePrice"] > 700000)]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 692         60       RL        104.0    21535   Pave    NA      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 692         Lvl    AllPub    Corner  ...        0     NA    NA          NA
#
#     MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 692       0      1   2007       WD         Normal     755000
#
# [1 rows x 80 columns]

# %%
df[(df["SaleCondition"] == "Abnorml") & (df["SalePrice"] > 700000)]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1183         60       RL        160.0    15623   Pave    NA      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# 1183         Lvl    AllPub    Corner  ...      555     Ex  MnPrv          NA
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 1183       0      7   2007       WD        Abnorml     745000
#
# [1 rows x 80 columns]

# %%
df[(df["TotalBsmtSF"] > 6000)]
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1299         60       RL        313.0    63887   Pave    NA      IR3
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# 1299         Bnk    AllPub    Corner  ...      480     Gd    NA          NA
#
#      MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 1299       0      1   2008      New        Partial     160000
#
# [1 rows x 80 columns]

# %%
df[df["KitchenAbvGr"] == 0]
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 955         90       RL         35.0     9400   Pave    NA      IR1
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                   ...
# 955         Lvl    AllPub   CulDSac  ...        0     NA    NA          NA
#
#     MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice
# Id
# 955       0     10   2006       WD        AdjLand     127500
#
# [1 rows x 80 columns]

# %%
info("KitchenAbvGr", output = False)
# Out:
# KitchenAbvGr: Kitchens above grade
# []

# %% [markdown]
# ### List of features with has high amount of 0 value

# %%
zero_var = ["WoodDeckSF", "ScreenPorch", "PoolArea", "OpenPorchSF", "MiscVal", "MasVnrArea",
            "LowQualFinSF", "GarageYrBlt", "GarageArea", "EnclosedPorch", "BsmtFinSF2",
            "BsmtFinSF1", "3SsnPorch", "2ndFlrSF"]

# %%
dats.drop([1,2,3])
# Out:
#    x  y   z
# 0  1  1   4
# 4  5  5  12

# %%
dats
# Out:
#    x  y   z
# 0  1  1   4
# 1  2  2   5
# 2  3  3   7
# 3  4  4  10
# 4  5  5  12

# %%
s = dats.set_index("z")
s
# Out:
#     x  y
# z
# 4   1  1
# 5   2  2
# 7   3  3
# 10  4  4
# 12  5  5

# %%
True * 1
# Out:
# 1
